# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = pd.read_csv('X_movies')
X.head()
# Out:
#    production_budget  worldwide_gross   title_year  aspect_ratio  duration.1  \
# 0        425000000.0     2.783919e+09  2009.000000      1.780000  178.000000
# 1        306000000.0     2.058662e+09  2002.130733      2.126976  108.577186
# 2        300000000.0     9.634204e+08  2007.000000      2.350000  169.000000
# 3        300000000.0     8.796209e+08  2015.000000      2.350000  148.000000
# 4        275000000.0     1.084439e+09  2012.000000      2.350000  164.000000
#
#          budget  imdb_score  facebook_likes
# 0  2.370000e+08         7.9          4834.0
# 1  4.045539e+07         7.1           143.0
# 2  3.000000e+08         7.1         48350.0
# 3  2.450000e+08         6.8         11700.0
# 4  2.500000e+08         8.5        106759.0

# %%
y = X['worldwide_gross']
X = X.drop('worldwide_gross', axis=1)

# %%
X.corr()
# Out:
#                    production_budget  title_year  aspect_ratio  duration.1  \
# production_budget           1.000000    0.207884      0.077459    0.276407
# title_year                  0.207884    1.000000      0.130532   -0.137662
# aspect_ratio                0.077459    0.130532      1.000000   -0.012645
# duration.1                  0.276407   -0.137662     -0.012645    1.000000
# budget                      0.185357    0.048664      0.011340    0.064252
# imdb_score                  0.033154   -0.178685      0.037765    0.315642
# facebook_likes              0.236820    0.124693      0.020656    0.121918
#
#                      budget  imdb_score  facebook_likes
# production_budget  0.185357    0.033154        0.236820
# title_year         0.048664   -0.178685        0.124693
# aspect_ratio       0.011340    0.037765        0.020656
# duration.1         0.064252    0.315642        0.121918
# budget             1.000000    0.019417        0.032591
# imdb_score         0.019417    1.000000        0.096663
# facebook_likes     0.032591    0.096663        1.000000

# %%
sns.heatmap(X.corr())

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model = Lasso()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# C:\Users\luife\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.429362266693286e+18, tolerance: 9637898649312960.0
#   positive)
# 0.5310929532543602

# %%
model.coef_
# Out:
# array([ 3.08643053e+00, -8.65252150e+04, -6.30630549e+06,  6.03220057e+04,
#        -1.12059643e-02,  2.80700249e+07,  9.19060796e+01])

# %%
var = np.floor(np.log10(np.abs(model.coef_)))

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.plot(var)
plt.xticks(np.arange(7), list(X.columns));

# %%
z = pd.concat([X, y], axis= 1)
sns.pairplot(z)

# %%
clase = pd.cut(X['production_budget'],8).cat.codes.rename('class')
clase
# Out:
# 0       7
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4099    0
# 4100    0
# 4101    0
# 4102    0
# 4103    0
# Name: class, Length: 4104, dtype: int8

# %%
z2 = pd.concat([X,clase], axis=1)
z2.head()
# Out:
#    production_budget   title_year  aspect_ratio  duration.1        budget  \
# 0        425000000.0  2009.000000      1.780000  178.000000  2.370000e+08
# 1        306000000.0  2002.130733      2.126976  108.577186  4.045539e+07
# 2        300000000.0  2007.000000      2.350000  169.000000  3.000000e+08
# 3        300000000.0  2015.000000      2.350000  148.000000  2.450000e+08
# 4        275000000.0  2012.000000      2.350000  164.000000  2.500000e+08
#
#    imdb_score  facebook_likes  class
# 0         7.9          4834.0      7
# 1         7.1           143.0      5
# 2         7.1         48350.0      5
# 3         6.8         11700.0      5
# 4         8.5        106759.0      5

# %%
sns.pairplot(z2, hue='class')

# %%
sns.heatmap(z.corr())

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression
